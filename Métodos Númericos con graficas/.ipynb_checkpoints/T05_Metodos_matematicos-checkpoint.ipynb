# %% [markdown]
# Metodos matematicos: Echo por Edmundo David Rdz. Mendoza Mat:1633164 para la clase de programación

# %%
run Metodo_de_biseccion.py
# Out:
# Este programa determina usando el metodo de biseccion la raiz real de fx=(e^(-x/4))*sen(4x)
# ¿desea evaluarlo en xl=0.1 y xu=1?(s/n)
# n
# ingrese xl: 1
# ingrese xu: 7
# xr es raiz aprox de f(x) cuando:
# f(X)= -2.18908246041943e-08
# xr= 6.2833251953125
# Error relativo=  5.828298331163911e-05

# %%
run Metodo_de_falsa_posicion.py
# Out:
# Este programa determina usando el metodo de falsa posición  la raiz real de f(x)=cos(In(x))
# ¿desea evaluarlo en xl=0.1 y xu=1?(s/n)
# s
# xr es raiz aprox de f(x) cuando
# f(X)= -2.8800795740475362e-05
# xr= 0.20788853656135306
# Error relativo=  0.0

# %%
run Meodo_de_Newton_Raphson.py
# Out:
# Utilice el método de Newton-Raphson para calcular la raíz de f(x) = cos⁴(4x)4x empleando como valor inicial x0=1
# ¿el valor inicial sera 1, y error aproximado sera de 0.0001 ¿desea cambiar el valor inicial por otro?(si/no)
# n
# Con un error aproximado de:  2.2188318805071028e-05
# La raiz de f(x) = cos⁴(4x)4x es:
# xr= 1.1781011968623663
